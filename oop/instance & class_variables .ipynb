# %%
class Student:
    
    Student.school="GOVT"
    count=0                   # why it's working hear.
    def __init__(self,no, name):
        self.roll_no= no
        self.name= name
        Student.count+=1                #To count no of objects in a class
        



std1=Student(1, "nithin")
std2=Student(2, "santhosh")
std3=Student(3, "nandini")

# %%
#class variables and instance variables.
class Student:
    school="GOVT"
    count=0
    def __init__(self,no, name):
        self.roll_no= no
        self.name= name
        Student.count+=1
                    
        



std1=Student(1, "nithin")
std2=Student(2, "santhosh")
std3=Student(3, "nandini")


print(std1.school)
print(Student.school)


std1.school="private"       # the instance attribute shadows the class attribute
Student.school="Government"

print(std1.school)  
print(Student.school)
print(std2.school)
print(std3.school)
print(std1.__dict__)

del std1.school

print(std1.school)
print(std1.__dict__)
print(Student.__dict__)

print(Student.count)
# Out:
# GOVT
# GOVT
# private
# Government
# Government
# Government
# {'roll_no': 1, 'name': 'nithin', 'school': 'private'}
# Government
# {'roll_no': 1, 'name': 'nithin'}
# {'__module__': '__main__', '__firstlineno__': 2, 'school': 'Government', 'count': 3, '__init__': <function Student.__init__ at 0x000001D6C23CFE20>, '__static_attributes__': ('name', 'roll_no'), '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>, '__doc__': None}
# 3
